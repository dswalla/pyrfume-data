# %% [markdown]
# # Molecule Feature & Distance Matrices

# %% [markdown]
# Import all the necessary packages:

# %%
import numpy as np
import pandas as pd
import pyrfume
from ast import literal_eval
from pyrfume.features import smiles_to_mordred, smiles_to_morgan
from sklearn.preprocessing import MinMaxScaler
from scipy.spatial.distance import pdist, squareform

# %% [markdown]
# Load the identifiers.csv and molecules.csv as DataFrames:

# %%
identifiers = pd.read_csv('identifiers.csv')
molecules = pd.read_csv('molecules.csv')

# %% [markdown]
# Gather all SMILES of molecules as a list:

# %%
smiles = molecules['IsomericSMILES'].tolist()

# %% [markdown]
# Obtain all mordred features from SMILES:

# %%
mordred_features = smiles_to_mordred(smiles)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Computing Mordred features...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 37.04it/s]
# There are 20 molecules and 1826 features

# %%
mordred_features.head()
# Out:
#                        ABC     ABCGG nAcid nBase    SpAbs_A   SpMax_A  \
# C1=CC=C(C=C1)C=O  5.656854   5.42766     0     0  10.424292  2.135779
# CCCC(=O)O         3.754314  4.057055     1     0   6.155367  1.902113
# CCC(=O)O          3.047207  3.305183     1     0   5.226252  1.847759
# CC(C)C(=O)O       3.932653  4.244375     1     0        6.0       2.0
# CCC(C)CC(=O)O     5.277917  5.655215     1     0   8.565187  2.042079
#
#                   SpDiam_A     SpAD_A   SpMAD_A   LogEE_A  ...     SRW10  \
# C1=CC=C(C=C1)C=O  4.271558  10.424292  1.303037  2.969338  ...  8.298291
# CCCC(=O)O         3.804226   6.155367  1.025895    2.5951  ...  7.131699
# CCC(=O)O          3.695518   5.226252   1.04525  2.408576  ...  6.834109
# CC(C)C(=O)O            4.0        6.0       1.0  2.610845  ...  7.626083
# CCC(C)CC(=O)O     4.084158   8.565187  1.070648  2.899769  ...    7.8842
#
#                      TSRW10          MW       AMW WPath WPol Zagreb1 Zagreb2  \
# C1=CC=C(C=C1)C=O  35.247635  106.041865  7.574419    64    7    34.0    36.0
# CCCC(=O)O         29.439488   88.052429  6.289459    32    3    20.0    18.0
# CCC(=O)O           27.25413   74.036779  6.730616    18    2    16.0    14.0
# CC(C)C(=O)O        30.69869   88.052429  6.289459    29    4    22.0    21.0
# CCC(C)CC(=O)O     34.080836   116.08373  5.804186    71    6    30.0    29.0
#
#                   mZagreb1  mZagreb2
# C1=CC=C(C=C1)C=O  2.611111       2.0
# CCCC(=O)O         3.611111  1.583333
# CCC(=O)O          3.361111  1.333333
# CC(C)C(=O)O       4.222222  1.444444
# CCC(C)CC(=O)O     4.722222       2.0
#
# [5 rows x 1826 columns]

# %% [markdown]
# Merge CIDs with DataFrame of features:

# %%
features = pd.merge(molecules, mordred_features, left_on='IsomericSMILES', right_index=True)
features = features.drop(['MolecularWeight', 'IsomericSMILES', 'IUPACName', 'name'], axis=1)
features.head()
# Out:
#     CID       ABC     ABCGG nAcid nBase    SpAbs_A   SpMax_A  SpDiam_A  \
# 0   240  5.656854   5.42766     0     0  10.424292  2.135779  4.271558
# 1   264  3.754314  4.057055     1     0   6.155367  1.902113  3.804226
# 2  1032  3.047207  3.305183     1     0   5.226252  1.847759  3.695518
# 3  6590  3.932653  4.244375     1     0        6.0       2.0       4.0
# 4  7755  5.277917  5.655215     1     0   8.565187  2.042079  4.084158
#
#       SpAD_A   SpMAD_A  ...     SRW10     TSRW10          MW       AMW WPath  \
# 0  10.424292  1.303037  ...  8.298291  35.247635  106.041865  7.574419    64
# 1   6.155367  1.025895  ...  7.131699  29.439488   88.052429  6.289459    32
# 2   5.226252   1.04525  ...  6.834109   27.25413   74.036779  6.730616    18
# 3        6.0       1.0  ...  7.626083   30.69869   88.052429  6.289459    29
# 4   8.565187  1.070648  ...    7.8842  34.080836   116.08373  5.804186    71
#
#   WPol Zagreb1 Zagreb2  mZagreb1  mZagreb2
# 0    7    34.0    36.0  2.611111       2.0
# 1    3    20.0    18.0  3.611111  1.583333
# 2    2    16.0    14.0  3.361111  1.333333
# 3    4    22.0    21.0  4.222222  1.444444
# 4    6    30.0    29.0  4.722222       2.0
#
# [5 rows x 1827 columns]

# %% [markdown]
# Make values in CIDs column in identifiers be list type and iterate through each one. If a stimulus contains multiple CIDs, then the feature vectors for the CIDs will averaged and a new row for this mixture stimulus is added to the features matrix:

# %%
identifiers['CIDs'] = identifiers['CIDs'].apply(literal_eval)

# %%
temp = pd.DataFrame()

for i, row in identifiers[['CIDs', 'conc']].iterrows():
    cids = row['CIDs']
    conc = row['conc']
    if len(cids) == 2 and conc == 1:
        cid1 = pd.DataFrame(features.loc[features['CID'] == cids[0]]).drop('CID', axis=1)
        cid2 = pd.DataFrame(features.loc[features['CID'] == cids[1]]).drop('CID', axis=1)
        combined = pd.concat([cid1, cid2]).mean()
        combined['CID'] = cids
        temp = pd.concat([temp, combined], axis=1)

temp = temp.T.reset_index(drop=True)
temp
# Out:
#          ABC     ABCGG nAcid nBase    SpAbs_A   SpMax_A  SpDiam_A     SpAD_A  \
# 0   5.357996  5.432081   0.0   0.0   9.916776  2.062411  4.124823   9.916776
# 1   5.629974  5.994146   1.0   0.0    9.02506  2.216046  4.358876    9.02506
# 2    6.65983  6.585253   0.5   0.0  10.374839  2.298271  4.596542  10.374839
# 3   6.453131  6.283695   0.5   0.0  11.303566  2.182425  4.291634  11.303566
# 4   5.113832  5.399176   0.5   0.0   9.085916   1.96945    3.9389   9.085916
# 5   4.979058  5.298847   1.0   0.0   7.696807  2.021039  4.042079   7.696807
# 6   8.439677   7.82508   0.5   0.5  13.828832  2.159652  4.258472  13.828832
# 7   7.269627   6.68739   0.5   0.5   12.20589  2.083531  4.106231   12.20589
# 8    6.55044  6.475896   0.0   0.0  10.796875  2.271754  4.543507  10.796875
# 9   4.814974  5.049282   1.0   0.0    8.24499  1.940854  3.881707    8.24499
# 10  5.516295  5.727246   1.0   0.0   7.928391  2.074481  4.148961   7.928391
# 11  9.766895  8.792444   0.0   0.5  15.685009  2.436883  4.812936  15.685009
# 12  8.663621  8.044613   0.5   0.5  14.430258  2.264906  4.395765  14.430258
# 13  8.330288  7.715724   0.5   0.5   13.97405  2.134579  4.208328   13.97405
# 14  5.182782  5.511859   1.0   0.0   8.668988  2.131695  4.190174   8.668988
# 15   7.71235  7.156986   0.5   0.5  12.592764  2.159652  4.258472  12.592764
# 33    54.0    59.5  3.652778  2.680556    [240, 17750155]
# 34    51.0    54.5  4.402778  2.722222   [8051, 17750155]
# 35    48.0    52.5  4.458333  2.444444   [8034, 51358282]
# 36    41.0    47.0  4.003472  1.930556      [7991, 82227]
# 37    24.0    23.5  4.347222  1.611111       [6590, 8314]
# 38    31.0    31.0  4.767361  1.979167      [8051, 11684]
# 39    25.0    23.0  4.166667      1.75      [7991, 10430]
# 40    32.0    32.5  3.666667       2.0        [240, 7755]
# 41    27.0    25.5  4.291667  1.916667      [7802, 10430]
# 42    30.0    28.0  4.947917    1.6875     [10430, 14057]
# 43    28.0    28.5  4.822917  1.659722      [6590, 11684]
# 44    34.0    34.0  3.791667  2.083333    [10430, 637511]
# 45    27.0    27.0  3.111111  1.791667         [240, 264]
# 46    30.0    30.0  4.947917  1.770833     [10430, 11684]
# 47    46.0    52.0  4.784722  1.868056     [14057, 82227]
# 48    25.0    23.0  4.166667      1.75        [264, 8034]
# 49    26.0    25.0  4.472222  1.722222      [8314, 10430]
# 50    29.0    27.5  4.416667  2.041667      [7802, 12587]
# 51    41.0    45.5  3.777778  2.152778   [1032, 51358282]
#
# [52 rows x 1827 columns]

# %% [markdown]
# Create a new DataFrame copy of features, with the CID column as a list of CIDs, then concatenate the temporary DataFrame of averaged features from mixtures:

# %%
all_features = features.copy()
all_features['CID'] = all_features[['CID']].apply(lambda x: [x['CID']], axis=1)

# %%
all_features = pd.concat([all_features, temp]).reset_index(drop=True)
all_features
# Out:
#                  CID       ABC     ABCGG nAcid nBase    SpAbs_A   SpMax_A  \
# 0              [240]  5.656854   5.42766     0     0  10.424292  2.135779
# 1              [264]  3.754314  4.057055     1     0   6.155367  1.902113
# 2             [1032]  3.047207  3.305183     1     0   5.226252  1.847759
# 3             [6590]  3.932653  4.244375     1     0        6.0       2.0
# 4             [7755]  5.277917  5.655215     1     0   8.565187  2.042079
# ..               ...       ...       ...   ...   ...        ...       ...
# 67    [14057, 82227]  6.843513   6.69461   0.5   0.0   9.784568  2.351712
# 68       [264, 8034]   4.57081  4.818809   0.5   0.0   7.313752  1.951057
# 69     [8314, 10430]  4.605285  4.973283   1.0   0.0   7.245708   2.02644
# 70     [7802, 12587]  5.223222  5.508533   0.5   0.0   8.940698  1.994522
# 71  [1032, 51358282]  6.487606  6.163612   0.5   0.0   10.94685  2.130344
#
#     SpDiam_A     SpAD_A   SpMAD_A  ...     SRW10     TSRW10          MW  \
# 0   4.271558  10.424292  1.303037  ...  8.298291  35.247635  106.041865
# 1   3.804226   6.155367  1.025895  ...  7.131699  29.439488   88.052429
# 2   3.695518   5.226252   1.04525  ...  6.834109   27.25413   74.036779
# 3        4.0        6.0       1.0  ...  7.626083   30.69869   88.052429
# 4   4.084158   8.565187  1.070648  ...    7.8842  34.080836   116.08373
# ..       ...        ...       ...  ...       ...        ...         ...
# 67  4.703424   9.784568  1.070765  ...  9.229582   38.92378  126.104465
# 68  3.902113   7.313752  1.042456  ...  7.435093  31.625324  101.078447
# 69  4.052881   7.245708  1.035101  ...   7.77341  32.450329   102.06808
# 70  3.989044   8.940698  1.117587  ...  7.680821  33.591856  115.094097
# 71  4.195185   10.94685  1.163681  ...  8.109999  42.747766  122.558213
#
#          AMW  WPath WPol Zagreb1 Zagreb2  mZagreb1  mZagreb2
# 0   7.574419     64    7    34.0    36.0  2.611111       2.0
# 1   6.289459     32    3    20.0    18.0  3.611111  1.583333
# 2   6.730616     18    2    16.0    14.0  3.361111  1.333333
# 3   6.289459     29    4    22.0    21.0  4.222222  1.444444
# 4   5.804186     71    6    30.0    29.0  4.722222       2.0
# ..       ...    ...  ...     ...     ...       ...       ...
# 67  5.519886   84.0  9.0    46.0    52.0  4.784722  1.868056
# 68  5.738013   53.0  4.0    25.0    23.0  4.166667      1.75
# 69  6.004005   47.0  5.0    26.0    25.0  4.472222  1.722222
# 70  5.495377   75.0  5.5    29.0    27.5  4.416667  2.041667
# 71  7.253482  129.5  9.5    41.0    45.5  3.777778  2.152778
#
# [72 rows x 1827 columns]

# %% [markdown]
# Reset the type of the CID columns for features and identifiers to strings so that they can be easily joined:

# %%
all_features['CID'] = all_features[['CID']].apply(lambda x: str(x['CID']), axis=1)
identifiers['CIDs'] = identifiers[['CIDs']].apply(lambda x: str(x['CIDs']), axis=1)
identifiers = identifiers[identifiers['conc'] != 0]
identifiers
# Out:
#      stimulus              CIDs  conc
# 0           1       [240, 7802]     1
# 2           3    [11684, 18840]     1
# 3           4           [18840]     1
# 5           6            [1032]     1
# 7           8     [7755, 82227]     1
# ..        ...               ...   ...
# 135       136    [14057, 82227]     1
# 136       137       [264, 8034]     1
# 138       139     [8314, 10430]     1
# 139       140     [7802, 12587]     1
# 141       142  [1032, 51358282]     1
#
# [72 rows x 3 columns]

# %% [markdown]
# Bring the stimuli identifiers into DataFrame and set the stimulus as the index:

# %%
stimuli_features = pd.merge(all_features, identifiers, left_on='CID', right_on='CIDs')
stimuli_features = stimuli_features.drop(['CID', 'CIDs', 'conc'], axis=1)
stimuli_features = stimuli_features.set_index('stimulus')

# %% [markdown]
# Normalize all columns of the features matrix, dropping columns that contain NaNs:

# %%
scaler = MinMaxScaler()
stimuli_features[stimuli_features.columns] = scaler.fit_transform(stimuli_features[stimuli_features.columns])
# Out:
# /home/dswalla/.local/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:461: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# /home/dswalla/.local/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:462: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %%
stimuli_features = stimuli_features.dropna(axis='columns')
stimuli_features
# Out:
#                ABC     ABCGG  nAcid  nBase   SpAbs_A   SpMax_A  SpDiam_A  \
# stimulus
# 70        0.309023  0.313771    0.0    0.0  0.372372  0.407554  0.407554
# 119       0.083732  0.111151    1.0    0.0  0.066559  0.076912  0.076912
# 6         0.000000  0.000000    1.0    0.0  0.000000  0.000000  0.000000
# 56        0.104851  0.138843    1.0    0.0  0.055429  0.215424  0.215424
# 118       0.264151  0.347411    1.0    0.0  0.239191  0.274966  0.274966
# ...            ...       ...    ...    ...       ...       ...       ...
# 136       0.449541  0.501067    0.5    0.0  0.326544  0.713103  0.713103
# 137       0.180418  0.223763    0.5    0.0  0.149542  0.146168  0.146168
# 139       0.184501  0.246599    1.0    0.0  0.144668  0.252838  0.252838
# 140       0.257674  0.325727    0.5    0.0  0.266092  0.207672  0.207672
# 142       0.407397  0.422569    0.5    0.0  0.409806  0.399863  0.353519
#
#             SpAD_A   SpMAD_A   LogEE_A  ...     SRW10    TSRW10        MW  \
# stimulus                                ...
# 70        0.372372  1.000000  0.459400  ...  0.451076  0.243894  0.246024
# 119       0.066559  0.270594  0.152808  ...  0.091680  0.066679  0.107739
# 6         0.000000  0.321536  0.000000  ...  0.000000  0.000000  0.000000
# 56        0.055429  0.202443  0.165708  ...  0.243986  0.105099  0.107739
# 118       0.239191  0.388381  0.402407  ...  0.323506  0.208293  0.323216
# ...            ...       ...       ...  ...       ...       ...       ...
# 136       0.326544  0.388688  0.576518  ...  0.737983  0.356059  0.400245
# 137       0.149542  0.314181  0.277386  ...  0.185148  0.133372  0.207870
# 139       0.144668  0.294825  0.292582  ...  0.289374  0.158544  0.215477
# 140       0.266092  0.511919  0.397577  ...  0.260850  0.193374  0.315608
# 142       0.409806  0.633232  0.447488  ...  0.393068  0.472734  0.372985
#
#                AMW     WPath      WPol   Zagreb1   Zagreb2  mZagreb1  mZagreb2
# stimulus
# 70        0.922029  0.120735  0.333333  0.310345  0.318841  0.000000  0.328767
# 119       0.425863  0.036745  0.066667  0.068966  0.057971  0.355556  0.123288
# 6         0.596209  0.000000  0.000000  0.000000  0.000000  0.266667  0.000000
# 56        0.425863  0.028871  0.133333  0.103448  0.101449  0.572840  0.054795
# 118       0.238483  0.139108  0.266667  0.241379  0.217391  0.750617  0.328767
# ...            ...       ...       ...       ...       ...       ...       ...
# 136       0.128705  0.173228  0.466667  0.517241  0.550725  0.772840  0.263699
# 137       0.212932  0.091864  0.133333  0.155172  0.130435  0.553086  0.205479
# 139       0.315640  0.076115  0.200000  0.172414  0.159420  0.661728  0.191781
# 140       0.119242  0.149606  0.233333  0.224138  0.195652  0.641975  0.349315
# 142       0.798104  0.292651  0.500000  0.431034  0.456522  0.414815  0.404110
#
# [72 rows x 1486 columns]

# %% [markdown]
# Calculate the euclidean distance between all pairs of stimuli:

# %%
distance_matrix = pdist(stimuli_features, 'euclidean')

# %% [markdown]
# Create functions to easily lookup feature distance (euclidian distance) between two stimuli:

# %%
def get_pdist_index(stim1, stim2, features):
    i = features.index.get_loc(stim1)
    j = features.index.get_loc(stim2)
    m = features.shape[0]
    if i > j:
        index = m * j + i - ((j + 2) * (j + 1)) // 2
    else:    
        index = m * i + j - ((i + 2) * (i + 1)) // 2
    return index

def feature_distance_from_stimuli(stim1, stim2, features, distance_matrix):
    i = get_pdist_index(stim1, stim2, features)
    return distance_matrix[i]

# %% [markdown]
# Test out a pair of stimuli:

# %%
dist = feature_distance_from_stimuli(70, 6, stimuli_features, distance_matrix)
print(dist)
# Out:
# 14.710942117834673

# %% [markdown]
# ## Conversion to squareform and write out to file

# %%
sqr = pd.DataFrame(squareform(distance_matrix))
sqr.head()
# Out:
#           0          1          2          3          4          5   \
# 0   0.000000  12.474607  14.710942  13.245094  12.371401  12.918498
# 1  12.474607   0.000000   7.347430   7.351617   6.671245  11.082668
# 2  14.710942   7.347430   0.000000   5.761759  11.310690  14.567134
# 3  13.245094   7.351617   5.761759   0.000000   9.050677  12.565252
# 4  12.371401   6.671245  11.310690   9.050677   0.000000   8.547679
#
#           6          7          8          9   ...         62         63  \
# 0  11.958554  13.430166  12.949262  11.836654  ...  13.774317  12.926530
# 1   4.561606  11.295092  10.821586   5.586102  ...   7.529168   7.859074
# 2   9.076145  14.429674  14.426078   8.276055  ...  12.380241   8.484698
# 3   7.944051  11.831288  12.460546   5.550132  ...   9.681710   3.984486
# 4   4.458944   7.872903   8.186836   5.870663  ...   6.646069   7.589858
#
#           64        65         66         67         68         69         70  \
# 0   7.117870  6.237304  12.508600  14.314662  11.666097  11.901443  12.155128
# 1   8.038837  6.237304   6.517481  12.930942   5.647546   4.224088   8.537239
# 2  12.221782  9.812967  10.312066  16.531130   9.960188   8.927435  12.357051
# 3  10.201615  8.708354   6.837714  13.304253   8.069576   6.386328   9.998956
# 4   6.813722  7.737866   5.215820   9.479585   4.620528   4.721606   5.084933
#
#           71
# 0  10.240167
# 1   9.918832
# 2  10.897982
# 3  10.209425
# 4   9.871111
#
# [5 rows x 72 columns]

# %%
sqr.index = stimuli_features.index
sqr.columns = stimuli_features.index
sqr.head()
# Out:
# stimulus        70         119        6          56         118        103  \
# stimulus
# 70         0.000000  12.474607  14.710942  13.245094  12.371401  12.918498
# 119       12.474607   0.000000   7.347430   7.351617   6.671245  11.082668
# 6         14.710942   7.347430   0.000000   5.761759  11.310690  14.567134
# 56        13.245094   7.351617   5.761759   0.000000   9.050677  12.565252
# 118       12.371401   6.671245  11.310690   9.050677   0.000000   8.547679
#
# stimulus        102        110        51         98   ...        122  \
# stimulus                                              ...
# 70        11.958554  13.430166  12.949262  11.836654  ...  13.774317
# 119        4.561606  11.295092  10.821586   5.586102  ...   7.529168
# 6          9.076145  14.429674  14.426078   8.276055  ...  12.380241
# 56         7.944051  11.831288  12.460546   5.550132  ...   9.681710
# 118        4.458944   7.872903   8.186836   5.870663  ...   6.646069
#
# stimulus        126        127       131        133        136        137  \
# stimulus
# 70        12.926530   7.117870  6.237304  12.508600  14.314662  11.666097
# 119        7.859074   8.038837  6.237304   6.517481  12.930942   5.647546
# 6          8.484698  12.221782  9.812967  10.312066  16.531130   9.960188
# 56         3.984486  10.201615  8.708354   6.837714  13.304253   8.069576
# 118        7.589858   6.813722  7.737866   5.215820   9.479585   4.620528
#
# stimulus        139        140        142
# stimulus
# 70        11.901443  12.155128  10.240167
# 119        4.224088   8.537239   9.918832
# 6          8.927435  12.357051  10.897982
# 56         6.386328   9.998956  10.209425
# 118        4.721606   5.084933   9.871111
#
# [5 rows x 72 columns]

# %%
sqr.to_csv('stimuli_feature_distance.csv')

# %%
sqr.loc[(119, 70)]
# Out:
# 12.474607257166252

# %% [markdown]
# ## Manual validation of pdist

# %%
def calculate_pdist_manual(stim1, stim2):
    dist_ex = np.linalg.norm(stimuli_features.loc[stim1].values - stimuli_features.loc[stim2].values)
    print(dist_ex)

# %%
calculate_pdist_manual(70, 6)
# Out:
# 14.710942117834673
